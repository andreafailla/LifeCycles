# %%
# Autoreload extension
# %load_ext autoreload    
# %autoreload 2

# Include local library paths
import sys, os
#cwd = os.getcwd()
cwd = '../../'
lib = 'lifecycles/'
pth = os.path.join(cwd, lib)
sys.path.append(pth)

import lifecycles as lcs
from lifecycles.flow_analysis import events_all
import lifecycles.classic_match as cm
from lifecycles import measures as m
import pandas as pd
import plotly.express as px
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import tnetwork as tn
from tnetwork import DCD

# %% [markdown]
# # Compute the groups

# %%
#tg = tn.graph_socioPatterns2012(format=tn.DynGraphSN)
tg = tn.graph_socioPatterns_Primary_School(format=tn.DynGraphSN)
#tg = tn.graph_socioPatterns_Hospital(format=tn.DynGraphSN)
# Out:
# graph will be loaded as:  <class 'tnetwork.dyn_graph.dyn_graph_sn.DynGraphSN'>

# %%
tg_day = tg.aggregate_time_period(period="hour")
#tg_day = tg.aggregate_sliding_window(60*60)

# %%
dyn_coms = DCD.iterative_match(tg_day)
# Out:
#   0% (0 of 20) |                         | Elapsed Time: 0:00:00 ETA:  --:--:--
# starting no_smoothing
#  15% (3 of 20) |###                      | Elapsed Time: 0:00:00 ETA:  00:00:00
#  40% (8 of 20) |##########               | Elapsed Time: 0:00:00 ETA:   0:00:00
#  60% (12 of 20) |##############          | Elapsed Time: 0:00:00 ETA:   0:00:00
#  85% (17 of 20) |####################    | Elapsed Time: 0:00:00 ETA:   0:00:00

# %%
tn.plot_as_graph(tg_day,dyn_coms,ts=tg_day.snapshots_timesteps()[:4])
# Out:
# /Users/remycazabet/opt/anaconda3/lib/python3.8/site-packages/numpy/core/numeric.py:2449: FutureWarning:
#
# elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison

# %%
def dynamic_cluster_to_snaps(dyn_coms):
    """
    Convert a dynamic cluster to a list of snapshots
    :param dyn_coms: a dynamic community object
    :return: a list of snapshots
    """
    snaps = []
    for t in dyn_coms.snapshots.keys():
        snap = dyn_coms.snapshots[t]
        snaps.append(snap.values())
    return snaps

# %%
snapsDay = dynamic_cluster_to_snaps(dyn_coms)
snapsDay.insert(10,[])
snapsDay.insert(0,[])
snapsDay.append([])

# %%
lc = lcs.LifeCycle(int)

# %%
lc.add_partitions_from(snapsDay)

# %%
lc.get_partition_at(13)
# Out:
# ['13_0',
#  '13_1',
#  '13_2',
#  '13_3',
#  '13_4',
#  '13_5',
#  '13_6',
#  '13_7',
#  '13_8',
#  '13_9']

# %% [markdown]
# # Visualize the flow

# %%
lc_start = lc.slice(0,5)

# %%
lcs.viz.plot_flow(lc_start)

# %% [markdown]
# # Compute events
# According to our method and references

# %%
cm.event_graph_greene(lc_start,0.1)
# Out:
# [(1, '1_0', '2_0', 0.18181818181818182),
#  (1, '1_1', '2_0', 0.22727272727272727),
#  (1, '1_2', '2_3', 0.9090909090909091),
#  (1, '1_3', '2_4', 0.7307692307692307),
#  (1, '1_4', '2_5', 0.7916666666666666),
#  (1, '1_5', '2_5', 0.125),
#  (1, '1_6', '2_7', 0.23809523809523808),
#  (1, '1_7', '2_6', 0.9),
#  (1, '1_8', '2_7', 0.38095238095238093),
#  (1, '1_9', '2_8', 0.9111111111111111),
#  (1, '1_10', '2_9', 0.9565217391304348),
#  (1, '1_11', '2_7', 0.23809523809523808),
#  (1, '1_14', '2_4', 0.11538461538461539),
#  (2, '2_0', '3_3', 0.4883720930232558),
#  (2, '2_1', '3_0', 0.6153846153846154),
#  (2, '2_2', '3_0', 0.38461538461538464),
#  (2, '2_3', '3_1', 0.9545454545454546),
#  (2, '2_4', '3_2', 1.0),
#  (2, '2_5', '3_3', 0.4666666666666667),
#  (2, '2_6', '3_4', 0.6896551724137931),
#  (2, '2_7', '3_5', 0.9047619047619048),
#  (2, '2_8', '3_4', 0.1044776119402985),
#  (2, '2_8', '3_6', 0.8444444444444444),
#  (2, '2_9', '3_7', 0.7333333333333333),
#  (3, '3_0', '4_2', 0.9259259259259259),
#  (3, '3_1', '4_3', 0.9130434782608695),
#  (3, '3_2', '4_4', 1.0),
#  (3, '3_3', '4_1', 0.4666666666666667),
#  (3, '3_3', '4_5', 0.4883720930232558),
#  (3, '3_4', '4_0', 0.15217391304347827),
#  (3, '3_4', '4_6', 0.7333333333333333),
#  (3, '3_5', '4_7', 0.8636363636363636),
#  (3, '3_6', '4_0', 0.37777777777777777),
#  (3, '3_6', '4_8', 0.5526315789473685),
#  (3, '3_7', '4_9', 0.7096774193548387)]

# %%
events_all(lc_start)
# Out:
# {'+': {'1_0': {'Death': 0.0,
#    'Dispersion': 0.0,
#    'Shrink': 0.0,
#    'Reduction': 0.0,
#    'Continue': 0.18181818181818182,
#    'Split': 0.0,
#    'Ancestor': 0.8181818181818181,
#    'Disassemble': 0.0},
#   '1_1': {'Death': 0.0,
#    'Dispersion': 0.0,
#    'Shrink': 0.0,
#    'Reduction': 0.0,
#    'Continue': 0.2272727272727273,
#    'Split': 0.0,
#    'Ancestor': 0.7727272727272727,
#    'Disassemble': 0.0},
#   '1_2': {'Death': 0.002267573696145127,
#    'Dispersion': 0.0,
#    'Shrink': 0.04535147392290249,
#    'Reduction': 0.0,
#    'Continue': 0.9070294784580498,
#    'Split': 0.0,
#    'Ancestor': 0.04535147392290254,
#    'Disassemble': 0.0},
#   '1_3': {'Death': 0.0,
#    'Dispersion': 0.0,
#    'Shrink': 0.0,
#    'Reduction': 0.0,
#    'Continue': 0.7307692307692308,
#    'Split': 0.0,
#    'Ancestor': 0.26923076923076916,
#    'Disassemble': 0.0},
#   '1_4': {'Death': 0.0,
#    'Dispersion': 0.0,
#    'Shrink': 0.0,
#    'Reduction': 0.0,
#    'Continue': 0.7916666666666666,
#    'Split': 0.0,
#    'Ancestor': 0.20833333333333337,
#    'Disassemble': 0.0},
#   '1_5': {'Death': 0.0,
#    'Dispersion': 0.0,
#    'Shrink': 0.0,
#    'Reduction': 0.0,
#    'Continue': 0.125,
#    'Split': 0.0,
#    'Ancestor': 0.875,
#    'Disassemble': 0.0},
#   '1_6': {'Death': 0.0,
#    'Dispersion': 0.0,
#    'Shrink': 0.0,
#    'Reduction': 0.0,
#    'Continue': 0.23809523809523808,
#    'Split': 0.0,
#    'Ancestor': 0.7619047619047619,
#    'Disassemble': 0.0},
#   '1_7': {'Death': 0.0,
#    'Dispersion': 0.0,
#    'Shrink': 0.0,
#    'Reduction': 0.0,
#    'Continue': 0.8999999999999999,
#    'Split': 0.0,
#    'Ancestor': 0.10000000000000009,
#    'Disassemble': 0.0},
#   '1_8': {'Death': 0.0,
#    'Dispersion': 0.0,
#    'Shrink': 0.0,
#    'Reduction': 0.0,
#    'Continue': 0.38095238095238093,
#    'Split': 0.0,
#    'Ancestor': 0.6190476190476191,
#    'Disassemble': 0.0},
#   '1_9': {'Death': 0.0,
#    'Dispersion': 0.0,
#    'Shrink': 0.0,
#    'Reduction': 0.0,
#    'Continue': 0.9111111111111111,
#    'Split': 0.0,
#    'Ancestor': 0.0888888888888889,
#    'Disassemble': 0.0},
#   '1_10': {'Death': 0.0,
#    'Dispersion': 0.0,
#    'Shrink': 0.043478260869565216,
#    'Reduction': 0.0,
#    'Continue': 0.9565217391304348,
#    'Split': 0.0,
#    'Ancestor': 0.0,
#    'Disassemble': 0.0},
#   '1_11': {'Death': 0.0,
#    'Dispersion': 0.0,
#    'Shrink': 0.0,
#    'Reduction': 0.0,
#    'Continue': 0.23809523809523808,
#    'Split': 0.0,
#    'Ancestor': 0.7619047619047619,
#    'Disassemble': 0.0},
#   '1_12': {'Death': 0.0,
#    'Dispersion': 0.0,
#    'Shrink': 0.0,
#    'Reduction': 0.0,
#    'Continue': 0.08888888888888889,
#    'Split': 0.0,
#    'Ancestor': 0.9111111111111111,
#    'Disassemble': 0.0},
#   '1_13': {'Death': 0.0,
#    'Dispersion': 0.0,
#    'Shrink': 0.0,
#    'Reduction': 0.0,
#    'Continue': 0.07692307692307693,
#    'Split': 0.0,
#    'Ancestor': 0.9230769230769231,
#    'Disassemble': 0.0},
#   '1_14': {'Death': 0.0,
#    'Dispersion': 0.0,
#    'Shrink': 0.0,
#    'Reduction': 0.0,
#    'Continue': 0.11538461538461538,
#    'Split': 0.0,
#    'Ancestor': 0.8846153846153846,
#    'Disassemble': 0.0},
#   '1_15': {'Death': 0.0,
#    'Dispersion': 0.0,
#    'Shrink': 0.0,
#    'Reduction': 0.0,
#    'Continue': 0.09090909090909091,
#    'Split': 0.0,
#    'Ancestor': 0.9090909090909091,
#    'Disassemble': 0.0},
#   '2_0': {'Death': 0.0,
#    'Dispersion': 0.0,
#    'Shrink': 0.0,
#    'Reduction': 0.0,
#    'Continue': 0.43526170798898073,
#    'Split': 0.043526170798898034,
#    'Ancestor': 0.47382920110192844,
#    'Disassemble': 0.047382920110192794},
#   '2_1': {'Death': 0.0,
#    'Dispersion': 0.0,
#    'Shrink': 0.0,
#    'Reduction': 0.0,
#    'Continue': 0.6153846153846154,
#    'Split': 0.0,
#    'Ancestor': 0.3846153846153846,
#    'Disassemble': 0.0},
#   '2_2': {'Death': 0.0,
#    'Dispersion': 0.0,
#    'Shrink': 0.0,
#    'Reduction': 0.0,
#    'Continue': 0.38461538461538464,
#    'Split': 0.0,
#    'Ancestor': 0.6153846153846154,
#    'Disassemble': 0.0},
#   '2_3': {'Death': 0.0,
#    'Dispersion': 0.0,
#    'Shrink': 0.0,
#    'Reduction': 0.0,
#    'Continue': 0.9545454545454546,
#    'Split': 0.0,
#    'Ancestor': 0.045454545454545414,
#    'Disassemble': 0.0},
#   '2_4': {'Death': 0.0,
#    'Dispersion': 0.0,
#    'Shrink': 0.0,
#    'Reduction': 0.0,
#    'Continue': 1.0,
#    'Split': 0.0,
#    'Ancestor': 0.0,
#    'Disassemble': 0.0},
#   '2_5': {'Death': 0.0,
#    'Dispersion': 0.0,
#    'Shrink': 0.0,
#    'Reduction': 0.0,
#    'Continue': 0.3375,
#    'Split': 0.1125,
#    'Ancestor': 0.41250000000000003,
#    'Disassemble': 0.1375},
#   '2_6': {'Death': 0.0,
#    'Dispersion': 0.0,
#    'Shrink': 0.0,
#    'Reduction': 0.0,
#    'Continue': 0.689655172413793,
#    'Split': 0.0,
#    'Ancestor': 0.31034482758620696,
#    'Disassemble': 0.0},
#   '2_7': {'Death': 0.0,
#    'Dispersion': 0.0,
#    'Shrink': 0.0,
#    'Reduction': 0.0,
#    'Continue': 0.7375661375661375,
#    'Split': 0.17354497354497353,
#    'Ancestor': 0.07195767195767197,
#    'Disassemble': 0.016931216931216932},
#   '2_8': {'Death': 0.0,
#    'Dispersion': 0.0,
#    'Shrink': 0.0,
#    'Reduction': 0.0,
#    'Continue': 0.6075947211579396,
#    'Split': 0.27439761600681145,
#    'Ancestor': 0.0812941677309493,
#    'Disassemble': 0.036713495104299686},
#   '2_9': {'Death': 0.0,
#    'Dispersion': 0.0,
#    'Shrink': 0.0,
#    'Reduction': 0.0,
#    'Continue': 0.7333333333333333,
#    'Split': 0.0,
#    'Ancestor': 0.2666666666666667,
#    'Disassemble': 0.0},
#   '3_0': {'Death': 0.0,
#    'Dispersion': 0.0,
#    'Shrink': 0.0,
#    'Reduction': 0.0,
#    'Continue': 0.8549801112188559,
#    'Split': 0.07124834260157127,
#    'Ancestor': 0.06809681185806722,
#    'Disassemble': 0.005674734321505598},
#   '3_1': {'Death': 0.0,
#    'Dispersion': 0.0,
#    'Shrink': 0.0,
#    'Reduction': 0.0,
#    'Continue': 0.8301211903439717,
#    'Split': 0.08301211903439709,
#    'Ancestor': 0.07896971874693748,
#    'Disassemble': 0.00789697187469374},
#   '3_2': {'Death': 0.0,
#    'Dispersion': 0.0,
#    'Shrink': 0.0,
#    'Reduction': 0.0,
#    'Continue': 1.0,
#    'Split': 0.0,
#    'Ancestor': 0.0,
#    'Disassemble': 0.0},
#   '3_3': {'Death': 0.0,
#    'Dispersion': 0.0,
#    'Shrink': 0.0,
#    'Reduction': 0.0,
#    'Continue': 0.0,
#    'Split': 0.9147727272727273,
#    'Ancestor': 0.0,
#    'Disassemble': 0.08522727272727271},
#   '3_4': {'Death': 0.0,
#    'Dispersion': 0.0,
#    'Shrink': 0.0,
#    'Reduction': 0.0,
#    'Continue': 0.4117445587551052,
#    'Split': 0.38429492150476496,
#    'Ancestor': 0.10549682055523957,
#    'Disassemble': 0.09846369918489029},
#   '3_5': {'Death': 0.0,
#    'Dispersion': 0.0,
#    'Shrink': 0.0,
#    'Reduction': 0.0,
#    'Continue': 0.8636363636363636,
#    'Split': 0.0,
#    'Ancestor': 0.13636363636363635,
#    'Disassemble': 0.0},
#   '3_6': {'Death': 0.0,
#    'Dispersion': 0.0,
#    'Shrink': 0.0,
#    'Reduction': 0.0,
#    'Continue': 0.09152816251154205,
#    'Split': 0.777989381348107,
#    'Ancestor': 0.01373499538319484,
#    'Disassemble': 0.11674746075715607},
#   '3_7': {'Death': 0.0,
#    'Dispersion': 0.0,
#    'Shrink': 0.0,
#    'Reduction': 0.0,
#    'Continue': 0.46257579980406066,
#    'Split': 0.26780704199182465,
#    'Ancestor': 0.17075753352927264,
#    'Disassemble': 0.09885962467484206}},
#  '-': {'1_0': {'Birth': 1.0,
#    'Accumulation': 0.0,
#    'Growth': 0.0,
#    'Expansion': 0.0,
#    'Continue': 0.0,
#    'Merge': 0.0,
#    'Offspring': 0.0,
#    'Reorganization': 0.0},
#   '1_1': {'Birth': 1.0,
#    'Accumulation': 0.0,
#    'Growth': 0.0,
#    'Expansion': 0.0,
#    'Continue': 0.0,
#    'Merge': 0.0,
#    'Offspring': 0.0,
#    'Reorganization': 0.0},
#   '1_2': {'Birth': 1.0,
#    'Accumulation': 0.0,
#    'Growth': 0.0,
#    'Expansion': 0.0,
#    'Continue': 0.0,
#    'Merge': 0.0,
#    'Offspring': 0.0,
#    'Reorganization': 0.0},
#   '1_3': {'Birth': 1.0,
#    'Accumulation': 0.0,
#    'Growth': 0.0,
#    'Expansion': 0.0,
#    'Continue': 0.0,
#    'Merge': 0.0,
#    'Offspring': 0.0,
#    'Reorganization': 0.0},
#   '1_4': {'Birth': 1.0,
#    'Accumulation': 0.0,
#    'Growth': 0.0,
#    'Expansion': 0.0,
#    'Continue': 0.0,
#    'Merge': 0.0,
#    'Offspring': 0.0,
#    'Reorganization': 0.0},
#   '1_5': {'Birth': 1.0,
#    'Accumulation': 0.0,
#    'Growth': 0.0,
#    'Expansion': 0.0,
#    'Continue': 0.0,
#    'Merge': 0.0,
#    'Offspring': 0.0,
#    'Reorganization': 0.0},
#   '1_6': {'Birth': 1.0,
#    'Accumulation': 0.0,
#    'Growth': 0.0,
#    'Expansion': 0.0,
#    'Continue': 0.0,
#    'Merge': 0.0,
#    'Offspring': 0.0,
#    'Reorganization': 0.0},
#   '1_7': {'Birth': 1.0,
#    'Accumulation': 0.0,
#    'Growth': 0.0,
#    'Expansion': 0.0,
#    'Continue': 0.0,
#    'Merge': 0.0,
#    'Offspring': 0.0,
#    'Reorganization': 0.0},
#   '1_8': {'Birth': 1.0,
#    'Accumulation': 0.0,
#    'Growth': 0.0,
#    'Expansion': 0.0,
#    'Continue': 0.0,
#    'Merge': 0.0,
#    'Offspring': 0.0,
#    'Reorganization': 0.0},
#   '1_9': {'Birth': 1.0,
#    'Accumulation': 0.0,
#    'Growth': 0.0,
#    'Expansion': 0.0,
#    'Continue': 0.0,
#    'Merge': 0.0,
#    'Offspring': 0.0,
#    'Reorganization': 0.0},
#   '1_10': {'Birth': 1.0,
#    'Accumulation': 0.0,
#    'Growth': 0.0,
#    'Expansion': 0.0,
#    'Continue': 0.0,
#    'Merge': 0.0,
#    'Offspring': 0.0,
#    'Reorganization': 0.0},
#   '1_11': {'Birth': 1.0,
#    'Accumulation': 0.0,
#    'Growth': 0.0,
#    'Expansion': 0.0,
#    'Continue': 0.0,
#    'Merge': 0.0,
#    'Offspring': 0.0,
#    'Reorganization': 0.0},
#   '1_12': {'Birth': 1.0,
#    'Accumulation': 0.0,
#    'Growth': 0.0,
#    'Expansion': 0.0,
#    'Continue': 0.0,
#    'Merge': 0.0,
#    'Offspring': 0.0,
#    'Reorganization': 0.0},
#   '1_13': {'Birth': 1.0,
#    'Accumulation': 0.0,
#    'Growth': 0.0,
#    'Expansion': 0.0,
#    'Continue': 0.0,
#    'Merge': 0.0,
#    'Offspring': 0.0,
#    'Reorganization': 0.0},
#   '1_14': {'Birth': 1.0,
#    'Accumulation': 0.0,
#    'Growth': 0.0,
#    'Expansion': 0.0,
#    'Continue': 0.0,
#    'Merge': 0.0,
#    'Offspring': 0.0,
#    'Reorganization': 0.0},
#   '1_15': {'Birth': 1.0,
#    'Accumulation': 0.0,
#    'Growth': 0.0,
#    'Expansion': 0.0,
#    'Continue': 0.0,
#    'Merge': 0.0,
#    'Offspring': 0.0,
#    'Reorganization': 0.0},
#   '2_0': {'Birth': 0.0,
#    'Accumulation': 0.0,
#    'Growth': 0.04545454545454544,
#    'Expansion': 0.4545454545454546,
#    'Continue': 0.04545454545454544,
#    'Merge': 0.4545454545454546,
#    'Offspring': 0.0,
#    'Reorganization': 0.0},
#   '2_1': {'Birth': 1.0,
#    'Accumulation': 0.0,
#    'Growth': 0.0,
#    'Expansion': 0.0,
#    'Continue': 0.0,
#    'Merge': 0.0,
#    'Offspring': 0.0,
#    'Reorganization': 0.0},
#   '2_2': {'Birth': 1.0,
#    'Accumulation': 0.0,
#    'Growth': 0.0,
#    'Expansion': 0.0,
#    'Continue': 0.0,
#    'Merge': 0.0,
#    'Offspring': 0.0,
#    'Reorganization': 0.0},
#   '2_3': {'Birth': 0.002267573696145127,
#    'Accumulation': 0.0,
#    'Growth': 0.04535147392290249,
#    'Expansion': 0.0,
#    'Continue': 0.9070294784580498,
#    'Merge': 0.0,
#    'Offspring': 0.04535147392290254,
#    'Reorganization': 0.0},
#   '2_4': {'Birth': 0.0,
#    'Accumulation': 0.0,
#    'Growth': 0.05128205128205128,
#    'Expansion': 0.025641025641025644,
#    'Continue': 0.6153846153846154,
#    'Merge': 0.30769230769230776,
#    'Offspring': 0.0,
#    'Reorganization': 0.0},
#   '2_5': {'Birth': 0.0,
#    'Accumulation': 0.0,
#    'Growth': 0.06060606060606061,
#    'Expansion': 0.022727272727272724,
#    'Continue': 0.6666666666666666,
#    'Merge': 0.24999999999999997,
#    'Offspring': 0.0,
#    'Reorganization': 0.0},
#   '2_6': {'Birth': 0.0,
#    'Accumulation': 0.0,
#    'Growth': 0.1,
#    'Expansion': 0.0,
#    'Continue': 0.9,
#    'Merge': 0.0,
#    'Offspring': 0.0,
#    'Reorganization': 0.0},
#   '2_7': {'Birth': 0.0,
#    'Accumulation': 0.0,
#    'Growth': 0.0238095238095238,
#    'Expansion': 0.11904761904761904,
#    'Continue': 0.14285714285714285,
#    'Merge': 0.7142857142857144,
#    'Offspring': 0.0,
#    'Reorganization': 0.0},
#   '2_8': {'Birth': 0.0,
#    'Accumulation': 0.0,
#    'Growth': 0.0,
#    'Expansion': 0.0,
#    'Continue': 0.8222222222222222,
#    'Merge': 0.1777777777777778,
#    'Offspring': 0.0,
#    'Reorganization': 0.0},
#   '2_9': {'Birth': 0.0,
#    'Accumulation': 0.0,
#    'Growth': 0.0,
#    'Expansion': 0.0,
#    'Continue': 0.9565217391304348,
#    'Merge': 0.0,
#    'Offspring': 0.04347826086956519,
#    'Reorganization': 0.0},
#   '3_0': {'Birth': 0.0,
#    'Accumulation': 0.0,
#    'Growth': 0.0,
#    'Expansion': 0.0,
#    'Continue': 0.23076923076923078,
#    'Merge': 0.7692307692307692,
#    'Offspring': 0.0,
#    'Reorganization': 0.0},
#   '3_1': {'Birth': 0.0,
#    'Accumulation': 0.0,
#    'Growth': 0.045454545454545456,
#    'Expansion': 0.0,
#    'Continue': 0.9545454545454546,
#    'Merge': 0.0,
#    'Offspring': 0.0,
#    'Reorganization': 0.0},
#   '3_2': {'Birth': 0.0,
#    'Accumulation': 0.0,
#    'Growth': 0.0,
#    'Expansion': 0.0,
#    'Continue': 1.0,
#    'Merge': 0.0,
#    'Offspring': 0.0,
#    'Reorganization': 0.0},
#   '3_3': {'Birth': 0.0,
#    'Accumulation': 0.0,
#    'Growth': 0.0,
#    'Expansion': 0.0,
#    'Continue': 0.0,
#    'Merge': 0.9147727272727273,
#    'Offspring': 0.0,
#    'Reorganization': 0.08522727272727271},
#   '3_4': {'Birth': 0.007269707624468514,
#    'Accumulation': 0.007828915903273786,
#    'Growth': 0.02593591178804745,
#    'Expansion': 0.027930981925589564,
#    'Continue': 0.3501348091386406,
#    'Merge': 0.3770682559954591,
#    'Offspring': 0.09814105293032493,
#    'Reorganization': 0.1056903646941961},
#   '3_5': {'Birth': 0.0,
#    'Accumulation': 0.0,
#    'Growth': 0.0,
#    'Expansion': 0.0,
#    'Continue': 0.9047619047619048,
#    'Merge': 0.0,
#    'Offspring': 0.09523809523809523,
#    'Reorganization': 0.0},
#   '3_6': {'Birth': 0.0,
#    'Accumulation': 0.0,
#    'Growth': 0.0,
#    'Expansion': 0.0,
#    'Continue': 0.8444444444444444,
#    'Merge': 0.0,
#    'Offspring': 0.15555555555555556,
#    'Reorganization': 0.0},
#   '3_7': {'Birth': 0.008706829593309182,
#    'Accumulation': 0.004124287702093822,
#    'Growth': 0.03653126564478606,
#    'Expansion': 0.0173042837264776,
#    'Continue': 0.5114377190270049,
#    'Merge': 0.24225997217068643,
#    'Offspring': 0.12189561430632856,
#    'Reorganization': 0.05774002782931351},
#   '4_0': {'Birth': 0.0,
#    'Accumulation': 0.0,
#    'Growth': 0.0,
#    'Expansion': 0.0,
#    'Continue': 0.16137010990118977,
#    'Merge': 0.22591815386166564,
#    'Offspring': 0.2552965567654769,
#    'Reorganization': 0.3574151794716676},
#   '4_1': {'Birth': 0.0,
#    'Accumulation': 0.0,
#    'Growth': 0.0,
#    'Expansion': 0.0,
#    'Continue': 0.3375,
#    'Merge': 0.1125,
#    'Offspring': 0.41250000000000003,
#    'Reorganization': 0.1375},
#   '4_2': {'Birth': 0.0,
#    'Accumulation': 0.0,
#    'Growth': 0.0,
#    'Expansion': 0.0,
#    'Continue': 0.8546199362767412,
#    'Merge': 0.07121832802306172,
#    'Offspring': 0.06845698680018197,
#    'Reorganization': 0.0057047489000151596},
#   '4_3': {'Birth': 0.002066115702479337,
#    'Accumulation': 0.0,
#    'Growth': 0.04338842975206612,
#    'Expansion': 0.0,
#    'Continue': 0.9111570247933886,
#    'Merge': 0.0,
#    'Offspring': 0.04338842975206608,
#    'Reorganization': 0.0},
#   '4_4': {'Birth': 0.0,
#    'Accumulation': 0.0,
#    'Growth': 0.0,
#    'Expansion': 0.0,
#    'Continue': 1.0,
#    'Merge': 0.0,
#    'Offspring': 0.0,
#    'Reorganization': 0.0},
#   '4_5': {'Birth': 0.0,
#    'Accumulation': 0.0,
#    'Growth': 0.0,
#    'Expansion': 0.0,
#    'Continue': 0.43526170798898073,
#    'Merge': 0.043526170798898034,
#    'Offspring': 0.47382920110192844,
#    'Reorganization': 0.047382920110192794},
#   '4_6': {'Birth': 0.0,
#    'Accumulation': 0.0,
#    'Growth': 0.0,
#    'Expansion': 0.0,
#    'Continue': 0.6643427298208604,
#    'Merge': 0.06327073617341523,
#    'Offspring': 0.24870074844000917,
#    'Reorganization': 0.023685785565715142},
#   '4_7': {'Birth': 0.0,
#    'Accumulation': 0.0,
#    'Growth': 0.0,
#    'Expansion': 0.0,
#    'Continue': 0.6380165289256199,
#    'Merge': 0.23925619834710743,
#    'Offspring': 0.08925619834710741,
#    'Reorganization': 0.03347107438016528},
#   '4_8': {'Birth': 0.0,
#    'Accumulation': 0.0,
#    'Growth': 0.0,
#    'Expansion': 0.0,
#    'Continue': 0.5526315789473684,
#    'Merge': 0.0,
#    'Offspring': 0.44736842105263164,
#    'Reorganization': 0.0},
#   '4_9': {'Birth': 0.0,
#    'Accumulation': 0.0,
#    'Growth': 0.0,
#    'Expansion': 0.0,
#    'Continue': 0.6419805147593428,
#    'Merge': 0.06114100140565166,
#    'Offspring': 0.27106296350152675,
#    'Reorganization': 0.025815520333478722}}}

# %%
cm.events_asur(lc_start)
# Out:
# {'merge': [{'src': '2_4',
#    'type': 'merge',
#    'score': 0.8076923076923077,
#    'ref_sets': ['1_3', '1_13']},
#   {'src': '2_4',
#    'type': 'merge',
#    'score': 0.8461538461538461,
#    'ref_sets': ['1_3', '1_14']},
#   {'src': '2_5',
#    'type': 'merge',
#    'score': 0.9166666666666666,
#    'ref_sets': ['1_4', '1_5']},
#   {'src': '2_7',
#    'type': 'merge',
#    'score': 0.6190476190476191,
#    'ref_sets': ['1_6', '1_8']},
#   {'src': '2_7',
#    'type': 'merge',
#    'score': 0.6190476190476191,
#    'ref_sets': ['1_8', '1_11']},
#   {'src': '2_8', 'type': 'merge', 'score': 1.0, 'ref_sets': ['1_9', '1_12']},
#   {'src': '3_0', 'type': 'merge', 'score': 1.0, 'ref_sets': ['2_1', '2_2']},
#   {'src': '3_3',
#    'type': 'merge',
#    'score': 0.9130434782608695,
#    'ref_sets': ['2_0', '2_5']},
#   {'src': '3_7',
#    'type': 'merge',
#    'score': 0.5227272727272727,
#    'ref_sets': ['2_0', '2_9']},
#   {'src': '3_7',
#    'type': 'merge',
#    'score': 0.5434782608695652,
#    'ref_sets': ['2_5', '2_9']},
#   {'src': '3_7',
#    'type': 'merge',
#    'score': 0.5581395348837209,
#    'ref_sets': ['2_7', '2_9']}],
#  'split': [{'src': '2_8',
#    'type': 'split',
#    'score': 0.6716417910447762,
#    'ref_sets': ['3_4', '3_6']},
#   {'src': '3_0',
#    'type': 'split',
#    'score': 0.5306122448979592,
#    'ref_sets': ['4_2', '4_9']},
#   {'src': '3_3',
#    'type': 'split',
#    'score': 0.9130434782608695,
#    'ref_sets': ['4_1', '4_5']},
#   {'src': '3_4',
#    'type': 'split',
#    'score': 0.6170212765957447,
#    'ref_sets': ['4_0', '4_6']},
#   {'src': '3_6',
#    'type': 'split',
#    'score': 0.8444444444444444,
#    'ref_sets': ['4_0', '4_8']},
#   {'src': '3_7',
#    'type': 'split',
#    'score': 0.5319148936170213,
#    'ref_sets': ['4_1', '4_9']},
#   {'src': '3_7',
#    'type': 'split',
#    'score': 0.5111111111111111,
#    'ref_sets': ['4_5', '4_9']},
#   {'src': '3_7',
#    'type': 'split',
#    'score': 0.5555555555555556,
#    'ref_sets': ['4_7', '4_9']}],
#  'birth': [{'src': '1_0', 'type': 'birth'},
#   {'src': '1_1', 'type': 'birth'},
#   {'src': '1_2', 'type': 'birth'},
#   {'src': '1_3', 'type': 'birth'},
#   {'src': '1_4', 'type': 'birth'},
#   {'src': '1_5', 'type': 'birth'},
#   {'src': '1_6', 'type': 'birth'},
#   {'src': '1_7', 'type': 'birth'},
#   {'src': '1_8', 'type': 'birth'},
#   {'src': '1_9', 'type': 'birth'},
#   {'src': '1_10', 'type': 'birth'},
#   {'src': '1_11', 'type': 'birth'},
#   {'src': '1_12', 'type': 'birth'},
#   {'src': '1_13', 'type': 'birth'},
#   {'src': '1_14', 'type': 'birth'},
#   {'src': '1_15', 'type': 'birth'},
#   {'src': '2_1', 'type': 'birth'},
#   {'src': '2_2', 'type': 'birth'}],
#  'death': [],
#  'continue': [{'src': '2_4', 'type': 'continue', 'ref_set': '3_2'},
#   {'src': '3_2', 'type': 'continue', 'ref_set': '4_4'}]}

# %% [markdown]
# # Detail checking for an event

# %%
m.facets(lc_start,"1_7","+")
# Out:
# {'U': 1, 'I': 0.8999999999999999, 'O': 0.0, 'size': 18}

# %%
m.event_weights(lc_start,"1_7","+")
# Out:
# {'Death': 0.0,
#  'Dispersion': 0.0,
#  'Shrink': 0.0,
#  'Reduction': 0.0,
#  'Continue': 0.8999999999999999,
#  'Split': 0.0,
#  'Ancestor': 0.10000000000000009,
#  'Disassemble': 0.0}

# %%
m.event(lc_start,"1_7")
# Out:
# {'+': ('Continue', 0.8999999999999999), '-': ('Birth', 1.0)}

# %%
def plot_longitudinal_events_distribution(lc,weight_by_size=False,direction="+",return_df=False):
    """
    Plot the distribution of events over time
    
    :param lc: a lifecycle
    :param weight_by_size: if True, the size of the group is taken into account
    :param direction: the direction of the lifecycle (default is +, but can be - as well)
    :return: a dataframe with columns t,type,value
    """

    events_by_time = []
    for name,stats in events_all(lc)[direction].items():
        group_size = len(lc.get_group(name))
        t=name.split("_")[0]
        for type, value in stats.items():
            val=value
            if weight_by_size:
                val = val*group_size
            events_by_time.append((t,type,val))
    #transforom into a df, with columns t,type,value
    df = pd.DataFrame.from_records(events_by_time,columns=["t","type","value"])
    df = df.groupby(["t","type"]).sum().reset_index()
    #plot as stacked bar
    #df.plot(kind='bar', stacked=True, x="t", y="value", color="type")
    if return_df:
        return df
    else:
        fig = px.bar(df, x="t", y="value", color="type")
        fig.show()

# %%
#df = plot_longitudinal_events_distribution(lc,weight_by_size=True,return_df=True)
df = plot_longitudinal_events_distribution(lc,weight_by_size=True,return_df=True,direction="-")

# %%
df
# Out:
#      t            type       value
# 0    1    Accumulation    0.000000
# 1    1           Birth  182.000000
# 2    1        Continue    0.000000
# 3    1       Expansion    0.000000
# 4    1          Growth    0.000000
# ..  ..             ...         ...
# 155  9       Expansion    2.184994
# 156  9          Growth    2.731916
# 157  9           Merge   13.660087
# 158  9       Offspring    4.443760
# 159  9  Reorganization    0.339913
#
# [160 rows x 3 columns]

# %%
#extract real hours
hours = list(dyn_coms.snapshots.keys())
print(hours)
hours.insert(10,hours[9]+3600)
hours.insert(0,hours[0]-3600)
hours.append(hours[-1]+3600)

#convert from timestamp to datetime
hours = [pd.to_datetime(h,unit="s") for h in hours]
print(hours)
#replace the date in the df such that t=1 is the first element of hours list
df["t"] = df["t"].astype(int)
#df["t"] = df["t"]-df["t"].min()
df["t"] = df["t"].apply(lambda x: hours[x])
# Out:
# [1254384000, 1254387600, 1254391200, 1254394800, 1254398400, 1254402000, 1254405600, 1254409200, 1254412800, 1254416400, 1254470400, 1254474000, 1254477600, 1254481200, 1254484800, 1254488400, 1254492000, 1254495600, 1254499200, 1254502800]
# [Timestamp('2009-10-01 07:00:00'), Timestamp('2009-10-01 08:00:00'), Timestamp('2009-10-01 09:00:00'), Timestamp('2009-10-01 10:00:00'), Timestamp('2009-10-01 11:00:00'), Timestamp('2009-10-01 12:00:00'), Timestamp('2009-10-01 13:00:00'), Timestamp('2009-10-01 14:00:00'), Timestamp('2009-10-01 15:00:00'), Timestamp('2009-10-01 16:00:00'), Timestamp('2009-10-01 17:00:00'), Timestamp('2009-10-01 18:00:00'), Timestamp('2009-10-02 08:00:00'), Timestamp('2009-10-02 09:00:00'), Timestamp('2009-10-02 10:00:00'), Timestamp('2009-10-02 11:00:00'), Timestamp('2009-10-02 12:00:00'), Timestamp('2009-10-02 13:00:00'), Timestamp('2009-10-02 14:00:00'), Timestamp('2009-10-02 15:00:00'), Timestamp('2009-10-02 16:00:00'), Timestamp('2009-10-02 17:00:00'), Timestamp('2009-10-02 18:00:00')]

# %%
fig = px.bar(df, x="t", y="value", color="type")
#replace x axis with hours
#fig.update_xaxes(type='category', categoryorder='array', categoryarray=hours)
#fig["layout"].update({"xaxis": {"tickformat": "%H:%M"}})
#plot every hour
#fig.update_xaxes(tickvals=hours, ticktext=hours, tickformat="%H:%M")
fig.show()
